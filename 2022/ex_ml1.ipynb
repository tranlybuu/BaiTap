# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets

# %% [markdown]
# Bài 1: Hãy trình bày cách đọc 1 tập dữ liệu vào bộ nhớ (ví dụ: Iris). Yêu cầu giải thích bằng lời và triển khai bằng code sau đó.

# %% [markdown]
# Để đọc một file csv từ bên ngoài, ta chỉ cần đưa tên của file csv hoặc đường dẫn vào hàm read_csv của thư viện pandas, nó sẽ trả về cho ta một DataFrame

# %%
df= pd.read_csv ('https://raw.githubusercontent.com/tranlybuu/BaiTap/main/2022/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Bài 2:
# Từ tập dữ liệu trong bộ nhớ nêu trên, hãy tiến hành mô tả bằng các thông số thống kê mô tả và hình vẽ tương ứng.

# %% [markdown]
# Kiểm tra kích thức của 1 dataframe bằng cách pandas.dataframe.shape và nó sẽ trả lại kích thước của tập dữ liệu

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# pandas.dataframe.info sẽ trả về tên các cột, các giá không rỗng, kiểu giá trị và mức sử dụng bộ nhớ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# Thống kê mô tả tập dữ liệu bao gồm giá trị trung bình, độ lệch chuẩn, giá trị lớn nhất,...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Tính toán mối tương quan theo cặp của các cột, không bao gồm giá trị NA / null.

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# Biểu đồ thể hiện mối quan hệ giữa Sepal Length và Sepal Width

# %%
fig = df[df.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Iris-Setosa')
df[df.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='Iris-versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='Iris-virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Mối quan hệ giữa Sepal Length và Sepal Width")
plt.show()

# %% [markdown]
# Biểu đồ thể hiện mối quan hệ giữa Petal Length và Petal Width

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Iris-Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='Iris-versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='Iris-virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Mối quan hệ giữa Petal Length và Petal Width")
plt.show()

# %% [markdown]
# Biểu đồ thể hiện mối quan hệ của các cột dữ liệu

# %%
df = df.drop(['Id'],axis=1)
sns.pairplot(df, hue="Species", size=3)
# Out:
# C:\Users\b00\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Biểu đồ thể hiện sự phân bố dữ liệu cho từng cột dữ liệu

# %%
df.plot(kind='box', layout=(1,4),)
plt.show()

# %% [markdown]
# Bài 3: Từ tập dữ liệu trong bộ nhớ nêu trên, hãy:

# %% [markdown]
# Trình bày cách xác định dữ liệu và xác định nhãn lớp. Code tương ứng

# %% [markdown]
# Dữ liệu Iris bao gồm 5 cột dữ liệu được quan sát, thu thập được 150 hàng dữ liệu về chiều dài và chiều rộng của cánh hoa và lá về 3 loại cây
#
# <tên_dataframe>.columns trả về kết quả là tên của các cột trong tập dữ liệu

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# Trình bày cách chia tập dữ liệu ban đầu thành tập dữ liệu huấn luyện và tập dữ liệu kiểm thử. Code tương ứng.

# %% [markdown]
# Chia ra X là tập dữ liệu gồm 4 cột chiều dài và chiều rộng của cánh hoa và lá; y là tập dữ liệu gồm tên các loại cây

# %%
X, y = datasets.load_iris(return_X_y=True)

# %% [markdown]
# Sử dụng Sklearn để train với tỉ lệ test =30% train =70%

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print("Kích thước tập dữ liệu train",X_train.shape)
print("Kích thước tập dữ liệu test",X_test.shape)
# Out:
# Kích thước tập dữ liệu train (105, 4)
# Kích thước tập dữ liệu test (45, 4)

# %% [markdown]
# Bài 4: Hãy trình bày lý thuyết về phương pháp 10-fold cross validation và code minh họa

# %% [markdown]
# Cross validation là một kỹ thuật lấy mẫu để đánh giá mô hình học máy trong trường hợp dữ liệu không được dồi dào cho lắm.
#
# k-fold có nghĩa là:
# + Tập dữ liệu (data) được chia thành k tập con không giao nhau (gọi là “fold”) có kích thước xấp xỉ nhau.
# + Mỗi lần lặp, một tập con trong k tập sẽ được dùng để làm tập kiểm thử, (k-1) tập còn lại sẽ được sử dụng làm tập huấn luyện.
# + k giá trị lỗi (mỗi giá trị tương ứng với mỗi “fold”) sẽ được tính trung bình cộng để thu được giá trị lỗi tổng thể.
#
# Tham số quan trọng trong kỹ thuật này là k, đại diện cho số nhóm mà dữ liệu sẽ được chia ra. Vì lý do đó, nó được mang tên k-fold cross-validation. Khi giá trị của k được lựa chọn, người ta sử dụng trực tiếp giá trị đó trong tên của phương pháp đánh giá
#
# Ví dụ với k=10, phương pháp sẽ mang tên 10-fold cross-validation.
#
# Kỹ thuật này thường bao gồm các bước như sau:
#
# - Xáo trộn dataset một cách ngẫu nhiên
# - Chia dataset thành k nhóm
# - Với mỗi nhóm:
#
#     Sử dụng nhóm hiện tại để đánh giá hiệu quả mô hình
#
#     Các nhóm còn lại được sử dụng để huấn luyện mô hình
#
#     Huấn luyện mô hình
#
#     Đánh giá và sau đó hủy mô hình
# - Tổng hợp hiệu quả của mô hình dựa từ các số liệu đánh giá

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# Tạo 1 ví dụ pipeline
pipeline = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=100, max_depth=4))

# Pass instance of pipeline and training and test data set
# cv=10 đại diện cho StratifiedKFold với 10fold
scores = cross_val_score(pipeline, X=X_train, y=y_train, cv=10, n_jobs=1)
print('Cross Validation accuracy scores:',scores)
print('Cross Validation accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
# Out:
# Cross Validation accuracy scores: [0.90909091 1.         0.90909091 1.         1.         1.
#  1.         0.8        1.         0.9       ]
# Cross Validation accuracy: 0.952 +/- 0.066

# %% [markdown]
# Bài 5: Hãy trình bày lý thuyết về các chủ điểm sau:
# - Bias là gì?
# - Overfitting là gì?
# - RMSE là gì?
# - Precision là gì?

# %% [markdown]
# Bias là sự sai lệch giữa giá trị mà model chúng ta dự đoán được với giá trị thật ( predict - ground truth). Mô hình với low bias thì chênh lệch giữa giá trị dự đoán và giá trị thật nhỏ => Mô hình tốt. Và ngược lại high bias thì chênh lệch giữa predict và ground truth lớn => Mô hình lỗi cao trên cả tập huấn luyện ( training) và tập kiểm thử ( testing) => Underfitting

# %% [markdown]
# Overfitting là mô hình quá khít với dữ liệu, nó sẽ đúng trên tập training nhưng trên tập test (kiểm thử ) thì kết quả rất tệ. Các mô hình này thường có bias nhỏ và độ phân tán dữ liệu lớn.

# %% [markdown]
# RMSE (Lỗi trung bình bình phương) là độ lệch chuẩn của phần dư ( lỗi dự đoán ). Phần dư là thước đo khoảng cách từ các điểm dữ liệu đường hồi quy; RMSE là thước đo mức độ lan truyền của những phần dư này. Nói cách khác, nó cho bạn biết mức độ tập trung của dữ liệu xung quanh dòng phù hợp nhất . Lỗi bình phương trung bình thường được sử dụng trong khí hậu học, dự báo và phân tích hồi quy để xác minh kết quả thí nghiệm.

# %% [markdown]
# Precision thể hiện sự chuẩn xác của model, giúp chúng ta hình dung độ tin cậy của mô hình học máy. Số này càng cao thì model phân loại càng chuẩn
#
# Độ tin cậy = Số lần phân loại đúng/(Số lần phân loại đúng + Số lần phân loại sai)

# %% [markdown]
# Bài 6: Hãy trình bày phương pháp đánh giá mô hình bằng cách sử dụng tập dữ liệu kiểm thử (test dataset) và code tương ứng

# %% [markdown]
# Độ tin cậy của mô hình được đánh giá dựa vào việc so sánh kết quả của model dự đoán và tập dữ liệu test
#
# Ví dụ ở đây y_true là tập dữ liệu test và y_pred tượng trưng cho tập dữ liệu model dự đoán

# %%
from __future__ import print_function
import numpy as np 

def acc(y_true, y_pred):
    correct = np.sum(y_true == y_pred)
    return float(correct)/y_true.shape[0]

y_true = np.array([0, 0, 0, 0, 1, 1, 1, 2, 2, 2])
y_pred = np.array([0, 1, 0, 2, 1, 1, 0, 2, 1, 2])
print('Độ tin cậy =', acc(y_true, y_pred))
# Out:
# Độ tin cậy = 0.6

# %% [markdown]
# Bài 7: Bạn hãy lựa chọn 1 tập dữ liệu phù hợp với bài toán hồi quy tuyến tính và xây dựng mô hình hồi quy tuyến tính theo từng bước (kèm với mô tả của từng bước)
# - Bước 1: Tải dữ liệu
# - Bước 2: Mô tả dữ liệu
# - Bước 3: Phân chia train – test (tỉ lệ 70% -30%)
# - Bước 4: Huấn luyện mô hình với train set (10-fold cross validation)
# - Bước 5: Kiểm thử mô hình với test set
# - Bước 6: Trình bày kết quả và nhận xét

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# **Bước 1:** Tải dữ liệu
#
# Lấy tập dữ liệu Iris

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# **Bước 2:** Mô tả dữ liệu

# %%
print("Kích thước của tập dữ liệu:",iris.data.shape)
# Out:
# Kích thước của tập dữ liệu: (150, 4)

# %%
print("Các cột giá trị:",iris.feature_names)
# Out:
# Các cột giá trị: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print("Có 3 loại cây được thu thập:",iris.target_names)
# Out:
# Có 3 loại cây được thu thập: ['setosa' 'versicolor' 'virginica']

# %%
print("Thông tin mô tả:",iris.DESCR)
# Out:
# Thông tin mô tả: .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %% [markdown]
# **Bước 3:** Phân chia train test với tỉ lệ 7/3

# %%
from sklearn.model_selection import train_test_split
X, y = datasets.load_iris(return_X_y=True)
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# **Bước 4:** Huấn luyện mô hình với train set

# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
lr = linear_model.LinearRegression()
lr.fit(X1_train, Y1_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Bước 5:** Kiểm thử mô hình với test set

# %%
Y_pred = lr.predict(X1_test)
plt.scatter(Y1_test, Y_pred)
plt.xlabel("Kết quả thực tế")
plt.ylabel("Kết quả dự đoán")
plt.show()

# %% [markdown]
# **Bước 6:** Trình bày kết quả

# %%
print("Accuracy:",lr.score(X1_test, Y1_test))
print("Mean squared error: %.2f" % mean_squared_error(Y1_test, Y_pred))
print("Coefficient of determination: %.2f" % r2_score(Y1_test, Y_pred))
# Out:
# Accuracy: 0.8998261101639005
# Mean squared error: 0.06
# Coefficient of determination: 0.90

# %% [markdown]
# Bài 8: Xây dựng mô hình hồi quy phi tuyến tính

# %% [markdown]
# Bài 9: Xây dựng mô hình hồi quy logistic

# %% [markdown]
# **Bước 4:** Huấn luyện mô hình với train set

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()
logisticRegr.fit(X1_train, Y1_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Bước 5:** Kiểm thử mô hình với test set

# %%
Y_pred = lr.predict(X1_test)
plt.scatter(Y1_test, Y_pred)
plt.xlabel("Kết quả thực tế")
plt.ylabel("Kết quả dự đoán")
plt.show()

# %% [markdown]
# **Bước 6:** Trình bày kết quả

# %%
print("Accuracy:",logisticRegr.score(X1_test, Y1_test))
print("Mean squared error: %.2f" % mean_squared_error(Y1_test, Y_pred))
print("Coefficient of determination: %.2f" % r2_score(Y1_test, Y_pred))
# Out:
# Accuracy: 0.9777777777777777
# Mean squared error: 0.06
# Coefficient of determination: 0.90
