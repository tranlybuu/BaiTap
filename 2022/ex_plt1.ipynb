# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70121634/158714249-5ba2d93e-f526-4a23-9b7c-cdb2557dc85e.png)

# %% [markdown]
# - Xác định đạo hàm bậc nhất và bậc hai của hàm số trên;
# - Tạo ra 1 vector x có 1500 phần tử với giá trị khởi đầu là -6 và kết thúc là 5 bằng hàm
# linspace();
# - Xây dựng vector y, y1 và y2 tương ứng hàm số y(x), y(x)
# ′, y(x)
# ′′ với giá trị các phần tử
# tương ứng được sinh ra từ việc sử dụng vector x ở trên làm tham số đầu vào;
# - Hãy tạo đối tượng fig (là đối tượng của lớp Figure) và đối tượng ax (là đối tượng của
# Axes) từ hàm subplot() để phục vụ việc vẽ hình đồ thị của các hàm số trên;
# - Sử dụng đối tượng ax để vẽ đồ thị cho hàm số y(x) tương ứng với tham số đầu vào là x và
# y và đặt tên cho đồ thị này là y(x);
#
# - Sử dụng đối tượng ax để vẽ đồ thị cho hàm số y
# ′(x) tương ứng với tham số đầu vào là x
# và y1 và đặt tên cho đồ thị này là y
# ′
# (x);
# - Sử dụng đối tượng ax để vẽ đồ thị cho hàm số y ′′(x) tương ứng với tham số đầu vào là x và y2 và đặt tên cho đồ thị này là y
# ′′(x);
#
# - Thiết lập tên cho các trục tọa độ: tung độ là y và hoành độ là x;
# - Hiển thị các tên của từng đồ thị lên hình vẽ (gợi ý: hàm legend()).
# Kết quả xuất ra file ảnh định dạng svg

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70121634/157592565-47617044-711f-4dcd-94df-b95e9951306c.png)

# %%
x_value = np.linspace(-6,5, num=1500)
y_value = x_value**3+x_value*3+7
y1_value = 3*(x_value**2)+3
y2_value = 6*x_value

# %%
fig, (ax,ax1,ax2) = plt.subplots(1,3, figsize=(12,4))
ax.plot(x_value,y_value, 'tab:orange')
ax.set_title("Đồ thị y(x)")
ax.set_ylabel("Giá trị y")
ax.set_xlabel("Giá trị x")
ax1.plot(x_value,y1_value, 'tab:blue')
ax1.set_title("Đồ thị y'(x)")
ax1.set_xlabel("Giá trị x")
ax2.plot(x_value,y2_value, 'tab:gray')
ax2.set_title("Đồ thị y''(x)")
ax2.set_xlabel("Giá trị x")
plt.show()
fig.savefig("ex_plt1.svg", format="svg")
