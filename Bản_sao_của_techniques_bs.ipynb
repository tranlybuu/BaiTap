# %% [markdown]
# <a href="https://colab.research.google.com/github/tranlybuu/bai1/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_techniques_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Tải 1 url về

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("http://vnexpress.net")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    VnExpress - Báo tiếng Việt nhiều người xem nhất
#   </title>
#   <meta content="VnExpress tin tức mới nhất - Thông tin nhanh &amp; chính xác được cập nhật hàng giờ. Đọc báo tin tức online Việt Nam &amp; Thế giới nóng nhất trong ngày về thể thao, thời sự, pháp luật, kinh doanh,..." name="description"/>
#   <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="keywords"/>
#   <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="news_keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=1" name="viewport">
#    <meta content="IE=100" http-equiv="X-UA-Compatible"/>
#    <meta content="1547540628876392" property="fb:app_id"/>
#    <meta content="1800" http-equiv="REFRESH"/>
# ...

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
path = 'C:\\Users\\DELL\\'
os.chdir(path)
os.mkdir('url_list') 
path1= path + t
os.chdir(path1)
file = "html_file" + ".txt"
f = open(file, "w")
f.write(html)
f.close()
print(f)

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
arr=[1,23,7,4,5,12,154,6435,34]
x=arr.pop(0)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-584f754b6fd4> in <module>()
#       1 arr=[1,23,7,4,5,12,154,6435,34]
# ----> 2 x=arr.pop[0]
#       3 print(arr)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
link_url=[]
for item in soup.find_all("a"):
  link = item.get("href")
  link_url.append(link)
for i in link_url:
    i=str(i)
    if i[:4]!="http":
        x=link_url.remove(i)
    else:
        print(i)
# Out:
# https://video.vnexpress.net/tin-tuc/thoi-su/5-tuyen-giao-thong-ket-noi-san-bay-long-thanh-4218002.html
# https://video.vnexpress.net/tin-tuc/thoi-su/5-tuyen-giao-thong-ket-noi-san-bay-long-thanh-4218002.html
# https://video.vnexpress.net/tin-tuc/thoi-su/5-tuyen-giao-thong-ket-noi-san-bay-long-thanh-4218002.html
# https://video.vnexpress.net/tin-tuc/thoi-su/5-tuyen-giao-thong-ket-noi-san-bay-long-thanh-4218002.html#box_comment_vne
# https://vnexpress.net/fbi-canh-bao-bieu-tinh-vu-trang-khap-nuoc-my-4219600.html
# https://vnexpress.net/fbi-canh-bao-bieu-tinh-vu-trang-khap-nuoc-my-4219600.html
# https://vnexpress.net/fbi-canh-bao-bieu-tinh-vu-trang-khap-nuoc-my-4219600.html#box_comment_vne
# https://vnexpress.net/trump-don-doc-nhung-ngay-cuoi-nhiem-ky-4219291.html
# https://vnexpress.net/trump-don-doc-nhung-ngay-cuoi-nhiem-ky-4219291.html
# https://vnexpress.net/trump-don-doc-nhung-ngay-cuoi-nhiem-ky-4219291.html#box_comment_vne
# https://vnexpress.net/quoc-gia-hanh-phuc-4219546.html
# ...
