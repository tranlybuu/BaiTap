# %% [markdown]
# <a href="https://colab.research.google.com/github/tranlybuu/bai1/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_B%E1%BA%A3n_sao_c%E1%BB%A7a_thuc_hanh_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# THỰC HÀNH TRỰC QUAN HÓA DỮ LIỆU NÂNG CAO

# %% [markdown]
# Trong thực tế, các chiều dữ liệu có thể được trực quan hóa từng đối một với nhau. Trong Python, những hình vẽ dạng này được gọi là paired plots.
#
# Hãy sử dụng tài liệu tham khảo dưới đây để áp dụng vẽ paired plots cho tập dữ liệu microbiome.csv và baseball.csv
#
# Lưu ý có giải thích code trong phần markdown tương ứng
#
# Link: https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/tranlybuu/OFF-code/main/baseball.csv?token=AQW7RIQW4EXKXAXIUFQVWVDAKQFMO&fbclid=IwAR2N29R1lBgxVE0rGT9-7FToeUhWqSY7KuBDKEZQXV5DkOG3KMiPTuT9RQg')
df1 = pd.read_csv('https://raw.githubusercontent.com/levantanfc11/NGONNGUR/main/microbiome.csv')
df1.head()
# Out:
#         Taxon  Patient  Tissue  Stool
# 0  Firmicutes        1     632    305
# 1  Firmicutes        2     136   4182
# 2  Firmicutes        3    1174    703
# 3  Firmicutes        4     408   3946
# 4  Firmicutes        5     831   8605

# %%
import seaborn as sns
sns.pairplot(df1, hue="Taxon")

# %%
sns.pairplot(df1, kind="Taxon")

# %%
sns.pairplot(df1, height=1.5)
