# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# Câu 1: Excavation Depth and Archaeology
#
# Four different excavation sites at an archeological area in New Mexico gave the following depths (cm) for significant archaeological discoveries.
#
# X1 = depths at Site I
#
# X2 = depths at Site II
#
# X3 = depths at Site III
#
# X4 = depths at Site IV
#
# Reference: Mimbres Mogollon Archaeology by Woosley and McIntyre, Univ. of New Mexico Press
#
# Xây dựng giải thuyết
# $$H_{0}: \mu_{1} = \mu_{2} = \mu_{3} = \mu_{4}$$
# $$H_{a}: \text{Tồn tại ít nhất một cặp } (\mu_{i}, \mu_{j}) \text{ có giá trị khác nhau}$$

# %%
df_1 = pd.read_excel('owan01.xls')
df_1
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#      X1    X2     X3    X4
# 0    93  85.0  100.0  96.0
# 1   120  45.0   75.0  58.0
# 2    65  80.0   65.0  95.0
# 3   105  28.0   40.0  90.0
# 4   115  75.0   73.0  65.0
# 5    82  70.0   65.0  80.0
# 6    99  65.0   50.0  85.0
# 7    87  55.0   30.0  95.0
# 8   100  50.0   45.0  82.0
# 9    90  40.0   50.0   NaN
# 10   78   NaN   45.0   NaN
# 11   95   NaN   55.0   NaN
# 12   93   NaN    NaN   NaN
# 13   88   NaN    NaN   NaN
# 14  110   NaN    NaN   NaN

# %% [markdown]
# Vì kích thước của các mẫu ở bài 1 là không bằng nhau nên không thể kiểm định ANOVA

# %%
#Hàm kiểm định ANOVA
def anova(a, b, c, d):
    print("Kiểm định ANOVA:")
    stat, pvalue = stats.f_oneway(a, b, c, d)
    print("Stat =", stat, "\n", "p value =", pvalue)
    if pvalue < 0.05:
        print("Có bằng chứng để bác bỏ giả thuyết H0")
    else:
        print("Chưa có bằng chứng để bác bỏ giả thuyết H0")


def anova1(a, b, c, d, e):
    print("Kiểm định ANOVA:")
    stat, pvalue = stats.f_oneway(a, b, c, d, e)
    print("Stat =", stat, "\n", "p value =", pvalue)
    if pvalue < 0.05:
        print("Có bằng chứng để bác bỏ giả thuyết H0")
    else:
        print("Chưa có bằng chứng để bác bỏ giả thuyết H0")

# %% [markdown]
# Câu 2:Apple Orchard Experiment
# Five types of root-stock were used in an apple orchard grafting experiment. The following data represent the extension growth (cm) after four years.
#
# X1 = extension growth for type I
# X2 = extension growth for type II
# X3 = extension growth for type III
# X4 = extension growth for type IV
# X5 = extension growth for type V
#
# Xây dựng giải thuyết
# $$H_{0}: \mu_{1} = \mu_{2} = \mu_{3} = \mu_{4} = \mu_{5}$$
# $$H_{a}: \text{Tồn tại ít nhất một cặp } (\mu_{i}, \mu_{j}) \text{ có giá trị khác nhau}$$

# %%
df_2 = pd.read_excel('owan02.xls')
df_2.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#      X1    X2    X3    X4    X5
# 0  2569  2074  2505  2838  1532
# 1  2928  2885  2315  2351  2552
# 2  2865  3378  2667  3001  3083
# 3  3844  3906  2390  2439  2330
# 4  3027  2782  3021  2199  2079

# %%
x1_c2 = df_2['X1'].to_numpy()
x2_c2 = df_2['X2'].to_numpy()
x3_c2 = df_2['X3'].to_numpy()
x4_c2 = df_2['X4'].to_numpy()
x5_c2 = df_2['X5'].to_numpy()

# %%
#sử dụng shapiro để kiểm tra phân phối chuẩn
from scipy.stats import shapiro
stat_2, p_2 = shapiro(df_2['X1'])
print("Kiểm tra phân phối chuẩn của X1:")
if p_2 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

stat1_1, p1_1 = shapiro(df_2['X2'])
print("Kiểm tra phân phối chuẩn của X2:")
if p1_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

stat2_1, p2_1 = shapiro(df_2['X3'])
print("Kiểm tra phân phối chuẩn của X3:")
if p2_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
stat3_1, p3_1 = shapiro(df_2['X4'])
print("Kiểm tra phân phối chuẩn của X4:")
if p3_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
stat4_1, p4_1 = shapiro(df_2['X5'])
print("Kiểm tra phân phối chuẩn của X5:")
if p4_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
# Out:
# Kiểm tra phân phối chuẩn của X1:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X2:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X3:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X4:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X5:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn

# %%
#dùng kolmogorov test kiểm tra phân phối chuẩn
mean_x1 = df_2['X1'].mean()
std_x1 = df_2['X1'].std()
kq_1 = (df_2['X1'] - mean_x1) / std_x1

from scipy.stats import kstest
stat3, p3 = kstest(kq_1, 'norm')
print("Kiểm tra phân phối chuẩn của X1:")
print('stat=%.3f, p=%.3f' % (stat3, p3))
if p3 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x2 = df_2['X2'].mean()
std_x2 = df_2['X2'].std()
kq_2 = (df_2['X2'] - mean_x2) / std_x2

stat4, p4 = kstest(kq_2, 'norm')
print("Kiểm tra phân phối chuẩn của X2:")
print('stat=%.3f, p=%.3f' % (stat4, p4))
if p4 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x3 = df_2['X3'].mean()
std_x3 = df_2['X3'].std()
kq_3 = (df_2['X3'] - mean_x3) / std_x3

stat5, p5 = kstest(kq_3, 'norm')
print("Kiểm tra phân phối chuẩn của X3:")
print('stat=%.3f, p=%.3f' % (stat5, p5))
if p5 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x4 = df_2['X4'].mean()
std_x4 = df_2['X4'].std()
kq_4 = (df_2['X4'] - mean_x4) / std_x4

stat6, p6 = kstest(kq_4, 'norm')
print("Kiểm tra phân phối chuẩn của X4")
print('stat=%.3f, p=%.3f' % (stat6, p6))
if p6 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x5 = df_2['X5'].mean()
std_x5 = df_2['X5'].std()
kq_5 = (df_2['X5'] - mean_x5) / std_x5

stat7, p7 = kstest(kq_5, 'norm')
print("Kiểm tra phân phối chuẩn của X5")
print('stat=%.3f, p=%.3f' % (stat7, p7))
if p7 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
# Out:
# Kiểm tra phân phối chuẩn của X1:
# stat=0.197, p=0.861
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X2:
# stat=0.187, p=0.897
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X3:
# stat=0.200, p=0.849
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X4
# stat=0.180, p=0.918
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X5
# stat=0.182, p=0.914
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn

# %%
#Dùng kiểm định Bartlett để kiểm tra tính thuần nhất của các features.
from scipy.stats import bartlett
stat8, p8 = bartlett(df_2['X1'], df_2['X2'], df_2['X3'], df_2['X4'], df_2['X5'])
print("Statistic =", stat8, "\n",
          "p_value =", p8)

if p8 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0. Điều này ngụ ý mẫu hiện tại không đồng nhất về phương sai')
#Dùng kiểm định Levene để kiểm tra tính thuần nhất của các features.
print("Kiểm định Levene:")
stat9, p9 = stats.levene(df_2['X1'], df_2['X2'], df_2['X3'], df_2['X4'], df_2['X5'])
if p9 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\n Điều này ngụ ý mẫu hiện tại không đồng nhất về phương sai')
# Out:
# Statistic = 1.505379741017298
#  p_value = 0.825688088344803
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai
# Kiểm định Levene:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai

# %%
print(anova1(x1_c2, x2_c2, x3_c2, x4_c2, x5_c2))
# Out:
# Kiểm định ANOVA:
# Stat = 1.3142198672637213
#  p value = 0.28382583646160114
# Chưa có bằng chứng để bác bỏ giả thuyết H0
# None

# %% [markdown]
# Câu 3: Red Dye Number 40
#
# S.W. Laagakos and F. Mosteller of Harvard University fed mice different doses of red dye number 40 and recorded the time of death in weeks. Results for female mice, dosage and time of death are shown in the data
#
# X1 = time of death for control group
#
# X2 = time of death for group with low dosage
#
# X3 = time of death for group with medium dosage
#
# X4 = time of death for group with high dosage
#
# Xây dựng giải thuyết
# $$H_{0}: \mu_{1} = \mu_{2} = \mu_{3} = \mu_{4}$$
# $$H_{a}: \text{Tồn tại ít nhất một cặp } (\mu_{i}, \mu_{j}) \text{ có giá trị khác nhau}$$

# %%
df_3 = pd.read_excel('owan03.xls')
df_3
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#      X1    X2    X3     X4
# 0    70  49.0  30.0   34.0
# 1    77  60.0  37.0   36.0
# 2    83  63.0  56.0   48.0
# 3    87  67.0  65.0   48.0
# 4    92  70.0  76.0   65.0
# 5    93  74.0  83.0   91.0
# 6   100  77.0  87.0   98.0
# 7   102  80.0  90.0  102.0
# 8   102  89.0  94.0    NaN
# 9   103   NaN  97.0    NaN
# 10   96   NaN   NaN    NaN

# %% [markdown]
# Vì kích thước của các mẫu ở bài 1 là không bằng nhau nên không thể kiểm định ANOVA

# %% [markdown]
# Câu 4: Business Startup Costs
#
# The following data represent business startup costs (thousands of dollars) for shops.
#
# X1 = startup costs for pizza
#
# X2 = startup costs for baker/donuts
#
# X3 = startup costs for shoe stores
#
# X4 = startup costs for gift shops
#
# X5 = startup costs for pet stores
#
# Xây dựng giải thuyết
# $$H_{0}: \mu_{1} = \mu_{2} = \mu_{3} = \mu_{4} = \mu_{5}$$
# $$H_{a}: \text{Tồn tại ít nhất một cặp } (\mu_{i}, \mu_{j}) \text{ có giá trị khác nhau}$$

# %%
df_4 = pd.read_excel('owan04.xls')
df_4
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#        X1     X2     X3     X4   X5
# 0    80.0  150.0   48.0  100.0   25
# 1   125.0   40.0   35.0   96.0   80
# 2    35.0  120.0   95.0   35.0   30
# 3    58.0   75.0   45.0   99.0   35
# 4   110.0  160.0   75.0   75.0   30
# 5   140.0   60.0  115.0  150.0   28
# 6    97.0   45.0   42.0   45.0   20
# 7    50.0  100.0   78.0  100.0   75
# 8    65.0   86.0   65.0  120.0   48
# 9    79.0   87.0  125.0   50.0   20
# 10   35.0   90.0    NaN    NaN   50
# 11   85.0    NaN    NaN    NaN   75
# 12  120.0    NaN    NaN    NaN   55
# 13    NaN    NaN    NaN    NaN   60
# 14    NaN    NaN    NaN    NaN   85
# 15    NaN    NaN    NaN    NaN  110

# %% [markdown]
# Vì kích thước của các mẫu ở bài 1 là không bằng nhau nên không thể kiểm định ANOVA

# %% [markdown]
# Câu 5: Weights of Football Players
#
# The following data represent weights (pounds) of a random sample of professional football players on the following teams.
#
# X1 = weights of players for the Dallas Cowboys
#
# X2 = weights of players for the Green Bay Packers
#
# X3 = weights of players for the Denver Broncos
#
# X4 = weights of players for the Miami Dolphins
#
# X5 = weights of players for the San Francisco Forty Niners
#
# Xây dựng giải thuyết
# $$H_{0}: \mu_{1} = \mu_{2} = \mu_{3} = \mu_{4} = \mu_{5}$$
# $$H_{a}: \text{Tồn tại ít nhất một cặp } (\mu_{i}, \mu_{j}) \text{ có giá trị khác nhau}$$

# %%
df_5 = pd.read_excel('owan05.xls')
df_5
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#      X1   X2   X3   X4   X5
# 0   250  260  270  260  247
# 1   255  271  250  255  249
# 2   255  258  281  265  255
# 3   264  263  273  257  247
# 4   250  267  257  268  244
# 5   265  254  264  263  245
# 6   245  255  233  247  249
# 7   252  250  254  253  260
# 8   266  248  268  251  217
# 9   246  240  252  252  208
# 10  251  254  256  266  228
# 11  263  275  265  264  253
# 12  248  270  252  210  249
# 13  228  225  256  236  223
# 14  221  222  235  225  221
# 15  223  230  216  230  228
# 16  220  225  241  232  271

# %%
x1_c5 = df_5['X1'].to_numpy()
x2_c5 = df_5['X2'].to_numpy()
x3_c5 = df_5['X3'].to_numpy()
x4_c5 = df_5['X4'].to_numpy()
x5_c5 = df_5['X5'].to_numpy()

# %%
#sử dụng shapiro để kiểm tra phân phối chuẩn
from scipy.stats import shapiro
stat_2, p_2 = shapiro(df_5['X1'])
print("Kiểm tra phân phối chuẩn của X1:")
if p_2 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
stat1_1, p1_1 = shapiro(df_5['X2'])
print("Kiểm tra phân phối chuẩn của X2:")
if p1_1 > 0.05:
   print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

stat2_1, p2_1 = shapiro(df_5['X3'])
print("Kiểm tra phân phối chuẩn của X3:")
if p2_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
stat3_1, p3_1 = shapiro(df_5['X4'])
print("Kiểm tra phân phối chuẩn của X4:")
if p3_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
stat4_1, p4_1 = shapiro(df_5['X5'])
print("Kiểm tra phân phối chuẩn của X5:")
if p4_1 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
# Out:
# Kiểm tra phân phối chuẩn của X1:
# Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn
# Kiểm tra phân phối chuẩn của X2:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X3:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X4:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X5:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn

# %%
#dùng kolmogorov test kiểm tra phân phối chuẩn
mean_x1 = df_5['X1'].mean()
std_x1 = df_5['X1'].std()
kq_1 = (df_5['X1'] - mean_x1) / std_x1

from scipy.stats import kstest
stat3, p3 = kstest(kq_1, 'norm')
print("Kiểm tra phân phối chuẩn của X1:")
print('stat=%.3f, p=%.3f' % (stat3, p3))
if p3 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x2 = df_5['X2'].mean()
std_x2 = df_5['X2'].std()
kq_2 = (df_5['X2'] - mean_x2) / std_x2

stat4, p4 = kstest(kq_2, 'norm')
print("Kiểm tra phân phối chuẩn của X2:")
print('stat=%.3f, p=%.3f' % (stat4, p4))
if p4 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x3 = df_5['X3'].mean()
std_x3 = df_5['X3'].std()
kq_3 = (df_5['X3'] - mean_x3) / std_x3

stat5, p5 = kstest(kq_3, 'norm')
print("Kiểm tra phân phối chuẩn của X3:")
print('stat=%.3f, p=%.3f' % (stat5, p5))
if p5 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x4 = df_5['X4'].mean()
std_x4 = df_5['X4'].std()
kq_4 = (df_5['X4'] - mean_x4) / std_x4

stat6, p6 = kstest(kq_4, 'norm')
print("Kiểm tra phân phối chuẩn của X4:")
print('stat=%.3f, p=%.3f' % (stat6, p6))
if p6 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
mean_x5 = df_5['X5'].mean()
std_x5 = df_5['X5'].std()
kq_5 = (df_5['X5'] - mean_x5) / std_x5

stat7, p7 = kstest(kq_5, 'norm')
print("Kiểm tra phân phối chuẩn của X5:")
print('stat=%.3f, p=%.3f' % (stat7, p7))
if p7 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại không tuân theo luật phân phối chuẩn')
# Out:
# Kiểm tra phân phối chuẩn của X1:
# stat=0.208, p=0.397
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X2:
# stat=0.158, p=0.733
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X3:
# stat=0.160, p=0.716
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X4:
# stat=0.193, p=0.491
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kiểm tra phân phối chuẩn của X5:
# stat=0.221, p=0.326
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý rằng các mẫu hiện tại tuân theo luật phân phối chuẩn

# %%
#Dùng kiểm định Bartlett để kiểm tra tính thuần nhất của các features.
from scipy.stats import bartlett
stat8, p8 = bartlett(df_5['X1'], df_5['X2'], df_5['X3'], df_5['X4'], df_5['X5'])
print("Statistic =", stat8, "\n",
          "p_value =", p8)

if p8 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0. Điều này ngụ ý mẫu hiện tại không đồng nhất về phương sai')

#Dùng kiểm định Levene để kiểm tra tính thuần nhất của các features.
print("Kiểm định Levene:")
stat9, p9 = stats.levene(df_5['X1'], df_5['X2'], df_5['X3'], df_5['X4'], df_5['X5'])
if p9 > 0.05:
    print('Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.\nĐiều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai')
else:
    print('Có bằng chứng thống kê để bác bỏ giả thuyết H0.\n Điều này ngụ ý mẫu hiện tại không đồng nhất về phương sai')
# Out:
# Statistic = 0.23906518343914643
#  p_value = 0.9934005503125588
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai
# Kiểm định Levene:
# Chưa có bằng chứng thống kê để bác bỏ giả thuyết H0.
# Điều này ngụ ý các mẫu hiện tại mang tính đồng nhất về phương sai

# %%
print(anova1(x1_c5, x2_c5, x3_c5, x4_c5, x5_c5))
# Out:
# Kiểm định ANOVA:
# Stat = 1.5750491966351665
#  p value = 0.18898555405394352
# Chưa có bằng chứng để bác bỏ giả thuyết H0
# None
